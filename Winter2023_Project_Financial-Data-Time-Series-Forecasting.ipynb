# %% [markdown]
# # Data Loading

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/ritvik02/Financial-Data-Time-Series-Forecasting-Using-Neural-Networks/main/Code/train_new.csv/train_new.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     A     AAL     AAP    AAPL   ABBV    ABC   ABMD    ABT   \
# 0  01/01/2015  40.94  53.630  159.28  110.38  65.44  90.16  38.06  45.02
# 1  02/01/2015  40.56  53.910  158.56  109.33  65.89  90.46  37.31  44.90
# 2  05/01/2015  39.80  53.875  156.47  106.25  64.65  89.69  37.07  44.91
# 3  06/01/2015  39.18  53.040  156.36  106.26  64.33  90.18  36.13  44.40
# 4  07/01/2015  39.70  53.010  159.72  107.75  66.93  91.98  37.28  44.76
#
#     ACN   ...   XLNX    XOM   XRAY      XRX    XYL      YUM     ZBH    ZION   \
# 0  89.31  ...  43.290  92.45  53.27  36.5155  38.07  52.3831  113.42  28.510
# 1  88.84  ...  43.600  92.83  51.93  36.2257  38.08  52.0236  112.59  28.290
# 2  87.34  ...  42.795  90.29  51.57  35.4353  35.71  50.9666  116.79  27.230
# 3  86.71  ...  42.180  89.81  50.93  34.9611  35.50  50.3410  115.80  26.190
# 4  88.53  ...  42.195  90.72  52.25  35.4089  35.78  52.0092  118.68  26.435
#
#     ZTS     Cash
# 0  43.03  0.0355
# 1  43.31  0.0152
# 2  43.05  0.0101
# 3  42.63  0.0253
# 4  43.51  0.0203
#
# [5 rows x 507 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'A ', 'AAL ', 'AAP ', 'AAPL ', 'ABBV ', 'ABC ', 'ABMD ',
#        'ABT ', 'ACN ',
#        ...
#        'XLNX ', 'XOM ', 'XRAY ', 'XRX ', 'XYL ', 'YUM ', 'ZBH ', 'ZION ',
#        'ZTS ', 'Cash'],
#       dtype='object', length=507)

# %%
# sum of null values in the data
data.isna().sum()
# Out:
# Unnamed: 0    0
# A             0
# AAL           0
# AAP           0
# AAPL          0
#              ..
# YUM           0
# ZBH           0
# ZION          0
# ZTS           0
# Cash          0
# Length: 507, dtype: int64

# %%
# # converting date column from object to datetime
# data['Unnamed: 0'] = pd.to_datetime(data['Unnamed: 0'])

# %% [markdown]
# # Trend Analysis

# %%
import matplotlib.pyplot as plt

# using matplotlib to plot the data
data.plot.line(x = 'Unnamed: 0', y = 'AAPL ')
plt.show()

# %%
# using matplotlib to plot the data
data.plot.line(x = 'Unnamed: 0', y = 'AAL ')
plt.show()

# %%
# using matplotlib to plot the data
data.plot.line(x = 'Unnamed: 0', y = 'ZBH ')
plt.show()

# %%
# using matplotlib to plot the data
data.plot.line(x = 'Unnamed: 0', y = 'ABMD ')
plt.show()

# %%
# using matplotlib to plot the data
data.plot.line(x = 'Unnamed: 0', y = 'YUM ')
plt.show()

# %% [markdown]
# # Selecting stock

# %%
data_stock = data['AAPL ']

# %%
data_stock.shape
# Out:
# (891,)

# %%
891 - 178
# Out:
# 713

# %%
data_stock_np = np.array(data_stock)

# %%
data_stock_np[-15]
# Out:
# 188.59

# %%
data_stock[:713].plot.line(x = 'Unnamed: 0', y = 'AAPL ')
plt.show()

# %%
data_stock[-178:].plot.line(x = 'Unnamed: 0', y = 'AAPL ')
plt.show()

# %%
data_stock[-15:].plot.line(x = 'Unnamed: 0', y = 'AAPL ')
plt.show()

# %% [markdown]
# # Utility function

# %%
from pandas import Series
from pandas import concat
from pandas import read_csv
import datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Bidirectional
from keras.layers import LSTM
from math import sqrt
from matplotlib import pyplot
import numpy
from tensorflow.keras import layers

# converting the series data to supervised data
def series_data_to_supervised_data(data, lag=1):
	df = pd.DataFrame(data)
	columns = [df.shift(i) for i in range(1, lag+1)]
	columns.append(df)
	df = concat(columns, axis=1)
	df.fillna(0, inplace=True)
	return df
 
# finding difference between rows
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)
 
# inverting the difference value
def inverse_the_difference(history_data, yhat, interval=1):
 
  return (yhat+history_data[-interval])
 
# scaling the difference
def scale(train, test):
	# scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)

	train = train.reshape(train.shape[0], train.shape[1])
	train_scaled = scaler.transform(train)

	test = test.reshape(test.shape[0], test.shape[1])
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled
 
# inverse the scaling 
def invert_scale(scaler, X, value):
	temp = [x for x in X] + [value]
	array = numpy.array(temp)
	array = array.reshape(1, len(array))
	data_inverted = scaler.inverse_transform(array)
	return data_inverted[0, -1]
 
# LSTM model
def fit_lstm(train, batchSize, epoch, neurons):
	X, y = train[:, 0:-1], train[:, -1]
	X = X.reshape(X.shape[0], 1, X.shape[1])
	model = Sequential()
	model.add(LSTM(neurons, batch_input_shape=(batchSize, X.shape[1], X.shape[2]), stateful=True))
	model.add(Dense(1))
 
	model.compile(loss='mean_squared_error', optimizer='adam')
	for i in range(epoch):
		model.fit(X, y, epochs=1, batch_size=batchSize, verbose=0, shuffle=False)
		model.reset_states()
	return model


# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

def fit_rnn(train,batchSize,epoch, neurons):
  X, y = train[:, 0:-1], train[:, -1]
  X = X.reshape(X.shape[0], 1, X.shape[1])

  
  #RNN model
  
  print("X.shape[1]), ",X.shape[1])
  print("X.shape[2]) ",X.shape[2])

  model = Sequential()
  model.add(layers.SimpleRNN(neurons, batch_input_shape=(batchSize, X.shape[1], X.shape[2])))
  model.add(layers.Dense(1))
  model.compile(loss='mean_squared_error', optimizer='adam')
 
 
  for i in range(epoch):
    model.fit(X, y, epochs=1, batch_size=batchSize, verbose=0, shuffle=False )
    model.reset_states()
  return model

# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]
  

# make a one-step forecast
def forecast_rnn(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]
  
def fit_cnn(train,batchSize,epoch, neurons):
  X, y = train[:, 0:-1], train[:, -1]
  X = X.reshape(X.shape[0], 1, X.shape[1])
  print("X.shape[1]), ",X.shape[1])
  print("X.shape[2]) ",X.shape[2])
  
  #CNN model
  model = Sequential()
  model.add(layers.Conv1D(neurons,1, batch_input_shape=(batchSize, X.shape[1], X.shape[2])))
  model.add(layers.GlobalMaxPooling1D())
  model.add(layers.Dense(1))
  model.compile(loss='mean_squared_error', optimizer='adam')
  
   #model.add(layers.Dense(3, activation='sigmoid'))
  for i in range(epoch):
    model.fit(X, y, epochs=1, batch_size=batchSize, verbose=0, shuffle=False )
    model.reset_states()
  return model


# make a one-step forecast
def forecast_cnn(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]
  

  
def fit_bilstm(train,batchSize,epoch, neurons):
  X, y = train[:, 0:-1], train[:, -1]
  X = X.reshape(X.shape[0], 1, X.shape[1])
  model = Sequential()


  print("X.shape[1]), ",X.shape[1])
  print("X.shape[2]) ",X.shape[2])
  
  # Bi LSTM Model
  model = Sequential()
  model.add(Bidirectional(LSTM(neurons, batch_input_shape=(batchSize, X.shape[1], X.shape[2]), stateful=True)))
  model.add(Dense(1))
  model.compile(loss='mean_squared_error', optimizer='adam')

  #model.add(layers.Dense(3, activation='sigmoid'))
  for i in range(epoch):
    model.fit(X, y, epochs=1, batch_size=batchSize, verbose=0, shuffle=False )
    model.reset_states()
  return model


# make a one-step forecast
def forecast_bilstm(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# %% [markdown]
# # LSTM

# %%
data_stock.shape
# Out:
# (891,)

# %%
0.20 * 891
# Out:
# 178.20000000000002

# %%
# modify data to be stationary
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-178], supervised_values[-178:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
lstm_model = fit_lstm(train_scaled, 1, 1, 4)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
lstm_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_lstm(lstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	#print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-178:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-178:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# 712/712 [==============================] - 1s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
#
#  Test RMSE: 2.401

# %% [markdown]
# ## Over 15 test rows

# %%
# modify data to be stationary
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-15], supervised_values[-15:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
lstm_model = fit_lstm(train_scaled, 1, 1, 4)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
lstm_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_lstm(lstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	#print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-15:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-15:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# 875/875 [==============================] - 1s 773us/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 4ms/step
#
#  Test RMSE: 0.951

# %% [markdown]
# # RNN

# %%
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-178], supervised_values[-178:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
lstm_model = fit_rnn(train_scaled, 1, 1, 4)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
lstm_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_rnn(lstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-178:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-178:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# X.shape[1]),  1
# X.shape[2])  1
# 712/712 [==============================] - 1s 640us/step
# 1/1 [==============================] - 0s 21ms/step
# Month=1, Predicted=150.672266, Expected=153.140000
# 1/1 [==============================] - 0s 18ms/step
# Month=2, Predicted=153.341337, Expected=154.230000
# 1/1 [==============================] - 0s 19ms/step
# Month=3, Predicted=154.395059, Expected=153.280000
# 1/1 [==============================] - 0s 19ms/step
# Month=4, Predicted=153.409803, Expected=154.120000
# 1/1 [==============================] - 0s 16ms/step
# Month=5, Predicted=154.280398, Expected=153.810000
# 1/1 [==============================] - 0s 21ms/step
# Month=6, Predicted=153.950954, Expected=154.480000
# 1/1 [==============================] - 0s 18ms/step
# Month=7, Predicted=154.637368, Expected=153.480000
# 1/1 [==============================] - 0s 20ms/step
# Month=8, Predicted=153.608876, Expected=155.390000
# 1/1 [==============================] - 0s 19ms/step
# Month=9, Predicted=155.572794, Expected=155.300000
# 1/1 [==============================] - 0s 15ms/step
# Month=10, Predicted=155.444601, Expected=155.840000
# 1/1 [==============================] - 0s 18ms/step
# Month=11, Predicted=155.995113, Expected=155.900000
# 1/1 [==============================] - 0s 15ms/step
# Month=12, Predicted=156.047074, Expected=156.550000
# 1/1 [==============================] - 0s 14ms/step
# Month=13, Predicted=156.707018, Expected=156.000000
# 1/1 [==============================] - 0s 14ms/step
# Month=14, Predicted=156.136898, Expected=156.990000
# 1/1 [==============================] - 0s 15ms/step
# Month=15, Predicted=157.153161, Expected=159.880000
# 1/1 [==============================] - 0s 14ms/step
# Month=16, Predicted=160.090841, Expected=160.470000
# 1/1 [==============================] - 0s 16ms/step
# Month=17, Predicted=160.625975, Expected=159.760000
# 1/1 [==============================] - 0s 19ms/step
# Month=18, Predicted=159.894122, Expected=155.980000
# 1/1 [==============================] - 0s 21ms/step
# Month=19, Predicted=156.030926, Expected=156.250000
# 1/1 [==============================] - 0s 19ms/step
# Month=20, Predicted=156.400552, Expected=156.170000
# 1/1 [==============================] - 0s 16ms/step
# Month=21, Predicted=156.314766, Expected=157.100000
# 1/1 [==============================] - 0s 11ms/step
# Month=22, Predicted=157.262045, Expected=156.410000
# 1/1 [==============================] - 0s 11ms/step
# Month=23, Predicted=156.544473, Expected=157.410000
# 1/1 [==============================] - 0s 17ms/step
# Month=24, Predicted=157.573349, Expected=163.050000
# 1/1 [==============================] - 0s 13ms/step
# Month=25, Predicted=163.387084, Expected=166.720000
# 1/1 [==============================] - 0s 2ms/step
# Month=26, Predicted=166.959644, Expected=169.040000
# 1/1 [==============================] - 0s 17ms/step
# Month=27, Predicted=169.233495, Expected=166.890000
# 1/1 [==============================] - 0s 15ms/step
# Month=28, Predicted=166.993758, Expected=168.110000
# 1/1 [==============================] - 0s 19ms/step
# Month=29, Predicted=168.277598, Expected=172.500000
# 1/1 [==============================] - 0s 19ms/step
# Month=30, Predicted=172.771467, Expected=174.250000
# 1/1 [==============================] - 0s 20ms/step
# Month=31, Predicted=174.428980, Expected=174.810000
# 1/1 [==============================] - 0s 19ms/step
# Month=32, Predicted=174.965457, Expected=176.240000
# 1/1 [==============================] - 0s 1ms/step
# Month=33, Predicted=176.411897, Expected=175.880000
# 1/1 [==============================] - 0s 3ms/step
# Month=34, Predicted=176.020117, Expected=174.670000
# 1/1 [==============================] - 0s 7ms/step
# Month=35, Predicted=174.794861, Expected=173.970000
# 1/1 [==============================] - 0s 18ms/step
# Month=36, Predicted=174.104297, Expected=171.340000
# 1/1 [==============================] - 0s 5ms/step
# Month=37, Predicted=171.430517, Expected=169.080000
# 1/1 [==============================] - 0s 1ms/step
# Month=38, Predicted=169.180886, Expected=171.100000
# 1/1 [==============================] - 0s 6ms/step
# Month=39, Predicted=171.285529, Expected=170.150000
# 1/1 [==============================] - 0s 10ms/step
# Month=40, Predicted=170.279803, Expected=169.980000
# 1/1 [==============================] - 0s 17ms/step
# Month=41, Predicted=170.123279, Expected=173.140000
# 1/1 [==============================] - 0s 17ms/step
# Month=42, Predicted=173.360135, Expected=174.960000
# 1/1 [==============================] - 0s 18ms/step
# Month=43, Predicted=175.140625, Expected=174.960000
# 1/1 [==============================] - 0s 17ms/step
# Month=44, Predicted=175.106085, Expected=174.970000
# 1/1 [==============================] - 0s 10ms/step
# Month=45, Predicted=175.116250, Expected=174.090000
# 1/1 [==============================] - 0s 15ms/step
# Month=46, Predicted=174.221085, Expected=173.070000
# 1/1 [==============================] - 0s 9ms/step
# Month=47, Predicted=173.198502, Expected=169.480000
# 1/1 [==============================] - 0s 12ms/step
# Month=48, Predicted=169.538241, Expected=171.850000
# 1/1 [==============================] - 0s 2ms/step
# Month=49, Predicted=172.044898, Expected=171.050000
# 1/1 [==============================] - 0s 15ms/step
# Month=50, Predicted=171.182526, Expected=169.800000
# 1/1 [==============================] - 0s 2ms/step
# Month=51, Predicted=169.924072, Expected=169.640000
# 1/1 [==============================] - 0s 7ms/step
# Month=52, Predicted=169.783444, Expected=169.010000
# 1/1 [==============================] - 0s 18ms/step
# Month=53, Predicted=169.145519, Expected=169.320000
# 1/1 [==============================] - 0s 16ms/step
# Month=54, Predicted=169.471220, Expected=169.370000
# 1/1 [==============================] - 0s 7ms/step
# Month=55, Predicted=169.516909, Expected=172.670000
# 1/1 [==============================] - 0s 15ms/step
# Month=56, Predicted=172.895235, Expected=171.700000
# 1/1 [==============================] - 0s 5ms/step
# Month=57, Predicted=171.829434, Expected=172.270000
# 1/1 [==============================] - 0s 21ms/step
# Month=58, Predicted=172.425629, Expected=172.220000
# 1/1 [==============================] - 0s 17ms/step
# Month=59, Predicted=172.365260, Expected=173.970000
# 1/1 [==============================] - 0s 6ms/step
# Month=60, Predicted=174.148980, Expected=176.420000
# 1/1 [==============================] - 0s 3ms/step
# Month=61, Predicted=176.617189, Expected=174.540000
# 1/1 [==============================] - 0s 8ms/step
# Month=62, Predicted=174.650422, Expected=174.350000
# 1/1 [==============================] - 0s 22ms/step
# Month=63, Predicted=174.492948, Expected=175.010000
# 1/1 [==============================] - 0s 17ms/step
# Month=64, Predicted=175.167193, Expected=175.010000
# 1/1 [==============================] - 0s 8ms/step
# Month=65, Predicted=175.156085, Expected=175.010000
# 1/1 [==============================] - 0s 1ms/step
# Month=66, Predicted=175.156085, Expected=170.570000
# 1/1 [==============================] - 0s 18ms/step
# Month=67, Predicted=170.593271, Expected=170.600000
# 1/1 [==============================] - 0s 16ms/step
# Month=68, Predicted=170.746579, Expected=171.080000
# 1/1 [==============================] - 0s 2ms/step
# Month=69, Predicted=171.234087, Expected=169.230000
# 1/1 [==============================] - 0s 18ms/step
# Month=70, Predicted=169.341130, Expected=169.230000
# 1/1 [==============================] - 0s 3ms/step
# Month=71, Predicted=169.376085, Expected=172.260000
# 1/1 [==============================] - 0s 3ms/step
# Month=72, Predicted=172.475571, Expected=172.230000
# 1/1 [==============================] - 0s 5ms/step
# Month=73, Predicted=172.375590, Expected=173.030000
# 1/1 [==============================] - 0s 12ms/step
# Month=74, Predicted=173.189676, Expected=175.000000
# 1/1 [==============================] - 0s 22ms/step
# Month=75, Predicted=175.184274, Expected=174.350000
# 1/1 [==============================] - 0s 19ms/step
# Month=76, Predicted=174.485171, Expected=174.330000
# 1/1 [==============================] - 0s 2ms/step
# Month=77, Predicted=174.475755, Expected=174.290000
# 1/1 [==============================] - 0s 6ms/step
# Month=78, Predicted=174.435425, Expected=175.280000
# 1/1 [==============================] - 0s 5ms/step
# Month=79, Predicted=175.443161, Expected=177.090000
# 1/1 [==============================] - 0s 15ms/step
# Month=80, Predicted=177.270388, Expected=177.090000
# 1/1 [==============================] - 0s 18ms/step
# Month=81, Predicted=177.236085, Expected=176.190000
# 1/1 [==============================] - 0s 8ms/step
# Month=82, Predicted=176.320720, Expected=179.100000
# 1/1 [==============================] - 0s 22ms/step
# Month=83, Predicted=179.311505, Expected=179.260000
# 1/1 [==============================] - 0s 16ms/step
# Month=84, Predicted=179.408726, Expected=178.460000
# 1/1 [==============================] - 0s 11ms/step
# Month=85, Predicted=178.592526, Expected=177.000000
# 1/1 [==============================] - 0s 17ms/step
# Month=86, Predicted=177.119789, Expected=177.040000
# 1/1 [==============================] - 0s 5ms/step
# Month=87, Predicted=177.186744, Expected=174.220000
# 1/1 [==============================] - 0s 23ms/step
# Month=88, Predicted=174.304753, Expected=171.110000
# 1/1 [==============================] - 0s 7ms/step
# Month=89, Predicted=171.185364, Expected=171.510000
# 1/1 [==============================] - 0s 18ms/step
# Month=90, Predicted=171.662731, Expected=167.960000
# 1/1 [==============================] - 0s 17ms/step
# Month=91, Predicted=168.019743, Expected=166.970000
# 1/1 [==============================] - 0s 9ms/step
# Month=92, Predicted=167.099062, Expected=167.430000
# 1/1 [==============================] - 0s 7ms/step
# Month=93, Predicted=167.583747, Expected=167.780000
# 1/1 [==============================] - 0s 4ms/step
# Month=94, Predicted=167.931890, Expected=160.500000
# 1/1 [==============================] - 0s 1ms/step
# Month=95, Predicted=160.378578, Expected=156.490000
# 1/1 [==============================] - 0s 1ms/step
# Month=96, Predicted=156.531674, Expected=163.030000
# 1/1 [==============================] - 0s 10ms/step
# Month=97, Predicted=163.420053, Expected=159.540000
# 1/1 [==============================] - 0s 7ms/step
# Month=98, Predicted=159.601970, Expected=155.150000
# 1/1 [==============================] - 0s 19ms/step
# Month=99, Predicted=155.175482, Expected=156.410000
# 1/1 [==============================] - 0s 2ms/step
# Month=100, Predicted=156.578398, Expected=162.710000
# 1/1 [==============================] - 0s 1ms/step
# Month=101, Predicted=163.085620, Expected=164.340000
# 1/1 [==============================] - 0s 4ms/step
# Month=102, Predicted=164.516242, Expected=167.370000
# 1/1 [==============================] - 0s 3ms/step
# Month=103, Predicted=167.585571, Expected=172.990000
# 1/1 [==============================] - 0s 5ms/step
# Month=104, Predicted=173.325950, Expected=172.430000
# 1/1 [==============================] - 0s 16ms/step
# Month=105, Predicted=172.566727, Expected=172.430000
# 1/1 [==============================] - 0s 16ms/step
# Month=106, Predicted=172.576085, Expected=171.850000
# 1/1 [==============================] - 0s 4ms/step
# Month=107, Predicted=171.986383, Expected=171.070000
# 1/1 [==============================] - 0s 2ms/step
# Month=108, Predicted=171.202883, Expected=172.500000
# 1/1 [==============================] - 0s 8ms/step
# Month=109, Predicted=172.671897, Expected=175.500000
# 1/1 [==============================] - 0s 17ms/step
# Month=110, Predicted=175.714541, Expected=178.970000
# 1/1 [==============================] - 0s 5ms/step
# Month=111, Predicted=179.201688, Expected=178.390000
# 1/1 [==============================] - 0s 3ms/step
# Month=112, Predicted=178.526383, Expected=178.120000
# 1/1 [==============================] - 0s 1ms/step
# Month=113, Predicted=178.261620, Expected=175.000000
# 1/1 [==============================] - 0s 6ms/step
# Month=114, Predicted=175.075028, Expected=176.210000
# 1/1 [==============================] - 0s 3ms/step
# Month=115, Predicted=176.377400, Expected=176.820000
# 1/1 [==============================] - 0s 17ms/step
# Month=116, Predicted=176.976322, Expected=176.670000
# 1/1 [==============================] - 0s 20ms/step
# Month=117, Predicted=176.813610, Expected=175.030000
# 1/1 [==============================] - 0s 13ms/step
# Month=118, Predicted=175.145914, Expected=176.940000
# 1/1 [==============================] - 0s 13ms/step
# Month=119, Predicted=177.122794, Expected=179.980000
# 1/1 [==============================] - 0s 11ms/step
# Month=120, Predicted=180.195916, Expected=181.720000
# 1/1 [==============================] - 0s 19ms/step
# Month=121, Predicted=181.898748, Expected=179.970000
# 1/1 [==============================] - 0s 16ms/step
# Month=122, Predicted=180.083445, Expected=178.440000
# 1/1 [==============================] - 0s 7ms/step
# Month=123, Predicted=178.558306, Expected=178.650000
# 1/1 [==============================] - 0s 4ms/step
# Month=124, Predicted=178.799555, Expected=178.020000
# 1/1 [==============================] - 0s 18ms/step
# Month=125, Predicted=178.155519, Expected=175.300000
# 1/1 [==============================] - 0s 20ms/step
# Month=126, Predicted=175.387825, Expected=175.240000
# 1/1 [==============================] - 0s 3ms/step
# Month=127, Predicted=175.385095, Expected=171.270000
# 1/1 [==============================] - 0s 17ms/step
# Month=128, Predicted=171.313313, Expected=168.850000
# 1/1 [==============================] - 0s 19ms/step
# Month=129, Predicted=168.946538, Expected=164.940000
# 1/1 [==============================] - 0s 4ms/step
# Month=130, Predicted=164.985748, Expected=172.770000
# 1/1 [==============================] - 0s 3ms/step
# Month=131, Predicted=173.238972, Expected=168.340000
# 1/1 [==============================] - 0s 22ms/step
# Month=132, Predicted=168.363714, Expected=166.480000
# 1/1 [==============================] - 0s 17ms/step
# Month=133, Predicted=166.590895, Expected=167.780000
# 1/1 [==============================] - 0s 17ms/step
# Month=134, Predicted=167.949206, Expected=167.780000
# 1/1 [==============================] - 0s 3ms/step
# Month=135, Predicted=167.926085, Expected=166.680000
# 1/1 [==============================] - 0s 8ms/step
# Month=136, Predicted=166.806990, Expected=168.390000
# 1/1 [==============================] - 0s 6ms/step
# Month=137, Predicted=168.568056, Expected=171.610000
# 1/1 [==============================] - 0s 22ms/step
# Month=138, Predicted=171.832297, Expected=172.800000
# 1/1 [==============================] - 0s 17ms/step
# Month=139, Predicted=172.967005, Expected=168.380000
# 1/1 [==============================] - 0s 5ms/step
# Month=140, Predicted=168.404157, Expected=170.050000
# 1/1 [==============================] - 0s 16ms/step
# Month=141, Predicted=170.227144, Expected=173.250000
# 1/1 [==============================] - 0s 14ms/step
# Month=142, Predicted=173.471572, Expected=172.440000
# 1/1 [==============================] - 0s 3ms/step
# Month=143, Predicted=172.572347, Expected=174.140000
# 1/1 [==============================] - 0s 940us/step
# Month=144, Predicted=174.317827, Expected=174.730000
# 1/1 [==============================] - 0s 13ms/step
# Month=145, Predicted=174.885975, Expected=175.820000
# 1/1 [==============================] - 0s 20ms/step
# Month=146, Predicted=175.985059, Expected=178.240000
# 1/1 [==============================] - 0s 3ms/step
# Month=147, Predicted=178.436323, Expected=177.840000
# 1/1 [==============================] - 0s 3ms/step
# Month=148, Predicted=177.979445, Expected=172.800000
# 1/1 [==============================] - 0s 7ms/step
# Month=149, Predicted=172.795430, Expected=165.720000
# 1/1 [==============================] - 0s 18ms/step
# Month=150, Predicted=165.609292, Expected=165.240000
# 1/1 [==============================] - 0s 18ms/step
# Month=151, Predicted=165.378093, Expected=162.940000
# 1/1 [==============================] - 0s 19ms/step
# Month=152, Predicted=163.039818, Expected=163.650000
# 1/1 [==============================] - 0s 4ms/step
# Month=153, Predicted=163.808072, Expected=164.220000
# 1/1 [==============================] - 0s 17ms/step
# Month=154, Predicted=164.375629, Expected=162.320000
# 1/1 [==============================] - 0s 7ms/step
# Month=155, Predicted=162.429947, Expected=165.260000
# 1/1 [==============================] - 0s 18ms/step
# Month=156, Predicted=165.472509, Expected=169.100000
# 1/1 [==============================] - 0s 8ms/step
# Month=157, Predicted=169.346714, Expected=176.570000
# 1/1 [==============================] - 0s 4ms/step
# Month=158, Predicted=177.016944, Expected=176.890000
# 1/1 [==============================] - 0s 2ms/step
# Month=159, Predicted=177.041387, Expected=183.830000
# 1/1 [==============================] - 0s 16ms/step
# Month=160, Predicted=184.244413, Expected=185.160000
# 1/1 [==============================] - 0s 8ms/step
# Month=161, Predicted=185.329818, Expected=186.050000
# 1/1 [==============================] - 0s 6ms/step
# Month=162, Predicted=186.211309, Expected=187.360000
# 1/1 [==============================] - 0s 15ms/step
# Month=163, Predicted=187.529409, Expected=190.040000
# 1/1 [==============================] - 0s 4ms/step
# Month=164, Predicted=190.244099, Expected=188.590000
# 1/1 [==============================] - 0s 16ms/step
# Month=165, Predicted=188.709999, Expected=188.150000
# 1/1 [==============================] - 0s 10ms/step
# Month=166, Predicted=188.288771, Expected=186.440000
# 1/1 [==============================] - 0s 2ms/step
# Month=167, Predicted=186.554352, Expected=188.180000
# 1/1 [==============================] - 0s 6ms/step
# Month=168, Predicted=188.358748, Expected=186.990000
# 1/1 [==============================] - 0s 5ms/step
# Month=169, Predicted=187.115252, Expected=186.310000
# 1/1 [==============================] - 0s 4ms/step
# Month=170, Predicted=186.444648, Expected=187.630000
# 1/1 [==============================] - 0s 20ms/step
# Month=171, Predicted=187.799613, Expected=187.160000
# 1/1 [==============================] - 0s 15ms/step
# Month=172, Predicted=187.298263, Expected=188.360000
# 1/1 [==============================] - 0s 16ms/step
# Month=173, Predicted=188.527202, Expected=188.150000
# 1/1 [==============================] - 0s 19ms/step
# Month=174, Predicted=188.292617, Expected=188.580000
# 1/1 [==============================] - 0s 27ms/step
# Month=175, Predicted=188.733238, Expected=188.580000
# 1/1 [==============================] - 0s 18ms/step
# Month=176, Predicted=188.726085, Expected=187.900000
# 1/1 [==============================] - 0s 16ms/step
# Month=177, Predicted=188.034648, Expected=187.500000
# 1/1 [==============================] - 0s 3ms/step
# Month=178, Predicted=187.639445, Expected=186.870000
#
#  Test RMSE: 2.366

# %% [markdown]
# ## Over 15 test rows

# %%
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-15], supervised_values[-15:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
lstm_model = fit_rnn(train_scaled, 1, 1, 4)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
lstm_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_rnn(lstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-15:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-15:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# X.shape[1]),  1
# X.shape[2])  1
# 875/875 [==============================] - 1s 741us/step
# 1/1 [==============================] - 0s 16ms/step
# Month=1, Predicted=190.252410, Expected=188.590000
# 1/1 [==============================] - 0s 15ms/step
# Month=2, Predicted=188.647669, Expected=188.150000
# 1/1 [==============================] - 0s 2ms/step
# Month=3, Predicted=188.245288, Expected=186.440000
# 1/1 [==============================] - 0s 8ms/step
# Month=4, Predicted=186.488041, Expected=188.180000
# 1/1 [==============================] - 0s 11ms/step
# Month=5, Predicted=188.357129, Expected=186.990000
# 1/1 [==============================] - 0s 23ms/step
# Month=6, Predicted=187.057322, Expected=186.310000
# 1/1 [==============================] - 0s 19ms/step
# Month=7, Predicted=186.396322, Expected=187.630000
# 1/1 [==============================] - 0s 18ms/step
# Month=8, Predicted=187.791340, Expected=187.160000
# 1/1 [==============================] - 0s 7ms/step
# Month=9, Predicted=187.254167, Expected=188.360000
# 1/1 [==============================] - 0s 19ms/step
# Month=10, Predicted=188.516829, Expected=188.150000
# 1/1 [==============================] - 0s 2ms/step
# Month=11, Predicted=188.253894, Expected=188.580000
# 1/1 [==============================] - 0s 16ms/step
# Month=12, Predicted=188.707894, Expected=188.580000
# 1/1 [==============================] - 0s 7ms/step
# Month=13, Predicted=188.691761, Expected=187.900000
# 1/1 [==============================] - 0s 17ms/step
# Month=14, Predicted=187.986322, Expected=187.500000
# 1/1 [==============================] - 0s 8ms/step
# Month=15, Predicted=187.596784, Expected=186.870000
#
#  Test RMSE: 1.044

# %% [markdown]
# # CNN Model

# %%
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-178], supervised_values[-178:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
cnn_model = fit_cnn(train_scaled, 1, 1, 1)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
cnn_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_cnn(cnn_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-178:], predictions))
print('Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-178:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# X.shape[1]),  1
# X.shape[2])  1
# 712/712 [==============================] - 1s 776us/step
# 1/1 [==============================] - 0s 16ms/step
# Month=1, Predicted=150.952815, Expected=153.140000
# 1/1 [==============================] - 0s 7ms/step
# Month=2, Predicted=152.858215, Expected=154.230000
# 1/1 [==============================] - 0s 7ms/step
# Month=3, Predicted=154.209513, Expected=153.280000
# 1/1 [==============================] - 0s 6ms/step
# Month=4, Predicted=153.614877, Expected=154.120000
# 1/1 [==============================] - 0s 19ms/step
# Month=5, Predicted=154.143062, Expected=153.810000
# 1/1 [==============================] - 0s 16ms/step
# Month=6, Predicted=154.033390, Expected=154.480000
# 1/1 [==============================] - 0s 15ms/step
# Month=7, Predicted=154.532676, Expected=153.480000
# 1/1 [==============================] - 0s 6ms/step
# Month=8, Predicted=153.823587, Expected=155.390000
# 1/1 [==============================] - 0s 19ms/step
# Month=9, Predicted=155.226670, Expected=155.300000
# 1/1 [==============================] - 0s 15ms/step
# Month=10, Predicted=155.485067, Expected=155.840000
# 1/1 [==============================] - 0s 7ms/step
# Month=11, Predicted=155.915322, Expected=155.900000
# 1/1 [==============================] - 0s 5ms/step
# Month=12, Predicted=156.058937, Expected=156.550000
# 1/1 [==============================] - 0s 2ms/step
# Month=13, Predicted=156.606160, Expected=156.000000
# 1/1 [==============================] - 0s 15ms/step
# Month=14, Predicted=156.265198, Expected=156.990000
# 1/1 [==============================] - 0s 17ms/step
# Month=15, Predicted=156.986933, Expected=159.880000
# 1/1 [==============================] - 0s 7ms/step
# Month=16, Predicted=159.545956, Expected=160.470000
# 1/1 [==============================] - 0s 8ms/step
# Month=17, Predicted=160.536612, Expected=159.760000
# 1/1 [==============================] - 0s 19ms/step
# Month=18, Predicted=160.053070, Expected=155.980000
# 1/1 [==============================] - 0s 10ms/step
# Month=19, Predicted=156.807858, Expected=156.250000
# 1/1 [==============================] - 0s 3ms/step
# Month=20, Predicted=156.372355, Expected=156.170000
# 1/1 [==============================] - 0s 7ms/step
# Month=21, Predicted=156.353325, Expected=157.100000
# 1/1 [==============================] - 0s 18ms/step
# Month=22, Predicted=157.107384, Expected=156.410000
# 1/1 [==============================] - 0s 16ms/step
# Month=23, Predicted=156.699586, Expected=157.410000
# 1/1 [==============================] - 0s 12ms/step
# Month=24, Predicted=157.405191, Expected=163.050000
# 1/1 [==============================] - 0s 16ms/step
# Month=25, Predicted=162.236911, Expected=166.720000
# 1/1 [==============================] - 0s 18ms/step
# Month=26, Predicted=166.250081, Expected=169.040000
# 1/1 [==============================] - 0s 17ms/step
# Month=27, Predicted=168.805249, Expected=166.890000
# 1/1 [==============================] - 0s 16ms/step
# Month=28, Predicted=167.433915, Expected=168.110000
# 1/1 [==============================] - 0s 18ms/step
# Month=29, Predicted=168.066867, Expected=172.500000
# 1/1 [==============================] - 0s 15ms/step
# Month=30, Predicted=171.904658, Expected=174.250000
# 1/1 [==============================] - 0s 12ms/step
# Month=31, Predicted=174.114542, Expected=174.810000
# 1/1 [==============================] - 0s 16ms/step
# Month=32, Predicted=174.881838, Expected=176.240000
# 1/1 [==============================] - 0s 16ms/step
# Month=33, Predicted=176.160285, Expected=175.880000
# 1/1 [==============================] - 0s 6ms/step
# Month=34, Predicted=176.112100, Expected=174.670000
# 1/1 [==============================] - 0s 22ms/step
# Month=35, Predicted=175.050169, Expected=173.970000
# 1/1 [==============================] - 0s 17ms/step
# Month=36, Predicted=174.261328, Expected=171.340000
# 1/1 [==============================] - 0s 17ms/step
# Month=37, Predicted=171.967530, Expected=169.080000
# 1/1 [==============================] - 0s 15ms/step
# Month=38, Predicted=169.643077, Expected=171.100000
# 1/1 [==============================] - 0s 21ms/step
# Month=39, Predicted=170.917508, Expected=170.150000
# 1/1 [==============================] - 0s 16ms/step
# Month=40, Predicted=170.484877, Expected=169.980000
# 1/1 [==============================] - 0s 17ms/step
# Month=41, Predicted=170.179003, Expected=173.140000
# 1/1 [==============================] - 0s 19ms/step
# Month=42, Predicted=172.758922, Expected=174.960000
# 1/1 [==============================] - 0s 7ms/step
# Month=43, Predicted=174.812348, Expected=174.960000
# 1/1 [==============================] - 0s 14ms/step
# Month=44, Predicted=175.129389, Expected=174.970000
# 1/1 [==============================] - 0s 14ms/step
# Month=45, Predicted=175.137647, Expected=174.090000
# 1/1 [==============================] - 0s 21ms/step
# Month=46, Predicted=174.412683, Expected=173.070000
# 1/1 [==============================] - 0s 19ms/step
# Month=47, Predicted=173.417071, Expected=169.480000
# 1/1 [==============================] - 0s 14ms/step
# Month=48, Predicted=170.274761, Expected=171.850000
# 1/1 [==============================] - 0s 16ms/step
# Month=49, Predicted=171.606539, Expected=171.050000
# 1/1 [==============================] - 0s 18ms/step
# Month=50, Predicted=171.358748, Expected=169.800000
# 1/1 [==============================] - 0s 17ms/step
# Month=51, Predicted=170.187137, Expected=169.640000
# 1/1 [==============================] - 0s 19ms/step
# Month=52, Predicted=169.837261, Expected=169.010000
# 1/1 [==============================] - 0s 17ms/step
# Month=53, Predicted=169.289134, Expected=169.320000
# 1/1 [==============================] - 0s 16ms/step
# Month=54, Predicted=169.435387, Expected=169.370000
# 1/1 [==============================] - 0s 22ms/step
# Month=55, Predicted=169.530679, Expected=172.670000
# 1/1 [==============================] - 0s 21ms/step
# Month=56, Predicted=172.264535, Expected=171.700000
# 1/1 [==============================] - 0s 16ms/step
# Month=57, Predicted=172.038361, Expected=172.270000
# 1/1 [==============================] - 0s 23ms/step
# Month=58, Predicted=172.340096, Expected=172.220000
# 1/1 [==============================] - 0s 19ms/step
# Month=59, Predicted=172.398099, Expected=173.970000
# 1/1 [==============================] - 0s 16ms/step
# Month=60, Predicted=173.834542, Expected=176.420000
# 1/1 [==============================] - 0s 19ms/step
# Month=61, Predicted=176.162603, Expected=174.540000
# 1/1 [==============================] - 0s 17ms/step
# Month=62, Predicted=175.036882, Expected=174.350000
# 1/1 [==============================] - 0s 13ms/step
# Month=63, Predicted=174.552487, Expected=175.010000
# 1/1 [==============================] - 0s 17ms/step
# Month=64, Predicted=175.064418, Expected=175.010000
# 1/1 [==============================] - 0s 22ms/step
# Month=65, Predicted=175.179389, Expected=175.010000
# 1/1 [==============================] - 0s 18ms/step
# Month=66, Predicted=175.179389, Expected=170.570000
# 1/1 [==============================] - 0s 22ms/step
# Month=67, Predicted=171.512829, Expected=170.600000
# 1/1 [==============================] - 0s 21ms/step
# Month=68, Predicted=170.764163, Expected=171.080000
# 1/1 [==============================] - 0s 15ms/step
# Month=69, Predicted=171.165774, Expected=169.230000
# 1/1 [==============================] - 0s 19ms/step
# Month=70, Predicted=169.721656, Expected=169.230000
# 1/1 [==============================] - 0s 14ms/step
# Month=71, Predicted=169.399389, Expected=172.260000
# 1/1 [==============================] - 0s 18ms/step
# Month=72, Predicted=171.901568, Expected=172.230000
# 1/1 [==============================] - 0s 17ms/step
# Month=73, Predicted=172.404615, Expected=173.030000
# 1/1 [==============================] - 0s 18ms/step
# Month=74, Predicted=173.060030, Expected=175.000000
# 1/1 [==============================] - 0s 21ms/step
# Month=75, Predicted=174.826218, Expected=174.350000
# 1/1 [==============================] - 0s 16ms/step
# Month=76, Predicted=174.632618, Expected=174.330000
# 1/1 [==============================] - 0s 7ms/step
# Month=77, Predicted=174.502873, Expected=174.290000
# 1/1 [==============================] - 0s 17ms/step
# Month=78, Predicted=174.466357, Expected=175.280000
# 1/1 [==============================] - 0s 21ms/step
# Month=79, Predicted=175.276933, Expected=177.090000
# 1/1 [==============================] - 0s 21ms/step
# Month=80, Predicted=176.944090, Expected=177.090000
# 1/1 [==============================] - 0s 19ms/step
# Month=81, Predicted=177.259389, Expected=176.190000
# 1/1 [==============================] - 0s 22ms/step
# Month=82, Predicted=176.516167, Expected=179.100000
# 1/1 [==============================] - 0s 20ms/step
# Month=83, Predicted=178.762472, Expected=179.260000
# 1/1 [==============================] - 0s 19ms/step
# Month=84, Predicted=179.401517, Expected=178.460000
# 1/1 [==============================] - 0s 16ms/step
# Month=85, Predicted=178.768748, Expected=177.000000
# 1/1 [==============================] - 0s 21ms/step
# Month=86, Predicted=177.423718, Expected=177.040000
# 1/1 [==============================] - 0s 17ms/step
# Month=87, Predicted=177.202421, Expected=174.220000
# 1/1 [==============================] - 0s 16ms/step
# Month=88, Predicted=174.880628, Expected=171.110000
# 1/1 [==============================] - 0s 16ms/step
# Month=89, Predicted=171.821146, Expected=171.510000
# 1/1 [==============================] - 0s 20ms/step
# Month=90, Predicted=171.609710, Expected=167.960000
# 1/1 [==============================] - 0s 16ms/step
# Month=91, Predicted=168.747793, Expected=166.970000
# 1/1 [==============================] - 0s 17ms/step
# Month=92, Predicted=167.311845, Expected=167.430000
# 1/1 [==============================] - 0s 17ms/step
# Month=93, Predicted=167.519258, Expected=167.780000
# 1/1 [==============================] - 0s 11ms/step
# Month=94, Predicted=167.888419, Expected=160.500000
# 1/1 [==============================] - 0s 8ms/step
# Month=95, Predicted=161.937553, Expected=156.490000
# 1/1 [==============================] - 0s 15ms/step
# Month=96, Predicted=157.357924, Expected=163.030000
# 1/1 [==============================] - 0s 4ms/step
# Month=97, Predicted=162.060132, Expected=159.540000
# 1/1 [==============================] - 0s 16ms/step
# Month=98, Predicted=160.317341, Expected=155.150000
# 1/1 [==============================] - 0s 20ms/step
# Month=99, Predicted=156.084119, Expected=156.410000
# 1/1 [==============================] - 0s 19ms/step
# Month=100, Predicted=156.359899, Expected=162.710000
# 1/1 [==============================] - 0s 22ms/step
# Month=101, Predicted=161.781940, Expected=164.340000
# 1/1 [==============================] - 0s 19ms/step
# Month=102, Predicted=164.225446, Expected=167.370000
# 1/1 [==============================] - 0s 17ms/step
# Month=103, Predicted=167.011568, Expected=172.990000
# 1/1 [==============================] - 0s 17ms/step
# Month=104, Predicted=172.180394, Expected=172.430000
# 1/1 [==============================] - 0s 3ms/step
# Month=105, Predicted=172.696940, Expected=172.430000
# 1/1 [==============================] - 0s 6ms/step
# Month=106, Predicted=172.599389, Expected=171.850000
# 1/1 [==============================] - 0s 17ms/step
# Month=107, Predicted=172.120424, Expected=171.070000
# 1/1 [==============================] - 0s 17ms/step
# Month=108, Predicted=171.375264, Expected=172.500000
# 1/1 [==============================] - 0s 15ms/step
# Month=109, Predicted=172.420285, Expected=175.500000
# 1/1 [==============================] - 0s 14ms/step
# Month=110, Predicted=175.146794, Expected=178.970000
# 1/1 [==============================] - 0s 18ms/step
# Month=111, Predicted=178.534921, Expected=178.390000
# 1/1 [==============================] - 0s 3ms/step
# Month=112, Predicted=178.660424, Expected=178.120000
# 1/1 [==============================] - 0s 17ms/step
# Month=113, Predicted=178.336422, Expected=175.000000
# 1/1 [==============================] - 0s 20ms/step
# Month=114, Predicted=175.712888, Expected=176.210000
# 1/1 [==============================] - 0s 19ms/step
# Month=115, Predicted=176.168609, Expected=176.820000
# 1/1 [==============================] - 0s 16ms/step
# Month=116, Predicted=176.883128, Expected=176.670000
# 1/1 [==============================] - 0s 5ms/step
# Month=117, Predicted=176.865519, Expected=175.030000
# 1/1 [==============================] - 0s 11ms/step
# Month=118, Predicted=175.485074, Expected=176.940000
# 1/1 [==============================] - 0s 15ms/step
# Month=119, Predicted=176.776670, Expected=179.980000
# 1/1 [==============================] - 0s 6ms/step
# Month=120, Predicted=179.619826, Expected=181.720000
# 1/1 [==============================] - 0s 4ms/step
# Month=121, Predicted=181.586284, Expected=179.970000
# 1/1 [==============================] - 0s 17ms/step
# Month=122, Predicted=180.444236, Expected=178.440000
# 1/1 [==============================] - 0s 17ms/step
# Month=123, Predicted=178.875912, Expected=178.650000
# 1/1 [==============================] - 0s 16ms/step
# Month=124, Predicted=178.782807, Expected=178.020000
# 1/1 [==============================] - 0s 17ms/step
# Month=125, Predicted=178.299134, Expected=175.300000
# 1/1 [==============================] - 0s 3ms/step
# Month=126, Predicted=175.943208, Expected=175.240000
# 1/1 [==============================] - 0s 1ms/step
# Month=127, Predicted=175.419841, Expected=171.270000
# 1/1 [==============================] - 0s 16ms/step
# Month=128, Predicted=172.130956, Expected=168.850000
# 1/1 [==============================] - 0s 16ms/step
# Month=129, Predicted=169.440949, Expected=164.940000
# 1/1 [==============================] - 0s 22ms/step
# Month=130, Predicted=165.790504, Expected=172.770000
# 1/1 [==============================] - 0s 16ms/step
# Month=131, Predicted=171.575416, Expected=168.340000
# 1/1 [==============================] - 0s 21ms/step
# Month=132, Predicted=169.281087, Expected=166.480000
# 1/1 [==============================] - 0s 17ms/step
# Month=133, Predicted=166.973398, Expected=167.780000
# 1/1 [==============================] - 0s 16ms/step
# Month=134, Predicted=167.722931, Expected=167.780000
# 1/1 [==============================] - 0s 4ms/step
# Month=135, Predicted=167.949389, Expected=166.680000
# 1/1 [==============================] - 0s 16ms/step
# Month=136, Predicted=167.041007, Expected=168.390000
# 1/1 [==============================] - 0s 20ms/step
# Month=137, Predicted=168.261510, Expected=171.610000
# 1/1 [==============================] - 0s 3ms/step
# Month=138, Predicted=171.218470, Expected=172.800000
# 1/1 [==============================] - 0s 17ms/step
# Month=139, Predicted=172.762093, Expected=168.380000
# 1/1 [==============================] - 0s 17ms/step
# Month=140, Predicted=169.319345, Expected=170.050000
# 1/1 [==============================] - 0s 18ms/step
# Month=141, Predicted=169.928478, Expected=173.250000
# 1/1 [==============================] - 0s 18ms/step
# Month=142, Predicted=172.861954, Expected=172.440000
# 1/1 [==============================] - 0s 20ms/step
# Month=143, Predicted=172.750490, Expected=174.140000
# 1/1 [==============================] - 0s 17ms/step
# Month=144, Predicted=174.013252, Expected=174.730000
# 1/1 [==============================] - 0s 16ms/step
# Month=145, Predicted=174.796612, Expected=175.820000
# 1/1 [==============================] - 0s 16ms/step
# Month=146, Predicted=175.799513, Expected=178.240000
# 1/1 [==============================] - 0s 17ms/step
# Month=147, Predicted=177.987829, Expected=177.840000
# 1/1 [==============================] - 0s 7ms/step
# Month=148, Predicted=178.079068, Expected=172.800000
# 1/1 [==============================] - 0s 15ms/step
# Month=149, Predicted=173.847348, Expected=165.720000
# 1/1 [==============================] - 0s 15ms/step
# Month=150, Predicted=167.122713, Expected=165.240000
# 1/1 [==============================] - 0s 23ms/step
# Month=151, Predicted=165.493004, Expected=162.940000
# 1/1 [==============================] - 0s 8ms/step
# Month=152, Predicted=163.510045, Expected=163.650000
# 1/1 [==============================] - 0s 18ms/step
# Month=153, Predicted=163.695708, Expected=164.220000
# 1/1 [==============================] - 0s 6ms/step
# Month=154, Predicted=164.290096, Expected=162.320000
# 1/1 [==============================] - 0s 20ms/step
# Month=155, Predicted=162.820366, Expected=165.260000
# 1/1 [==============================] - 0s 6ms/step
# Month=156, Predicted=164.917246, Expected=169.100000
# 1/1 [==============================] - 0s 3ms/step
# Month=157, Predicted=168.600467, Expected=176.570000
# 1/1 [==============================] - 0s 18ms/step
# Month=158, Predicted=175.438128, Expected=176.890000
# 1/1 [==============================] - 0s 20ms/step
# Month=159, Predicted=177.003645, Expected=183.830000
# 1/1 [==============================] - 0s 2ms/step
# Month=160, Predicted=182.790453, Expected=185.160000
# 1/1 [==============================] - 0s 16ms/step
# Month=161, Predicted=185.097705, Expected=186.050000
# 1/1 [==============================] - 0s 2ms/step
# Month=162, Predicted=186.064352, Expected=187.360000
# 1/1 [==============================] - 0s 4ms/step
# Month=163, Predicted=187.301189, Expected=190.040000
# 1/1 [==============================] - 0s 10ms/step
# Month=164, Predicted=189.742537, Expected=188.590000
# 1/1 [==============================] - 0s 16ms/step
# Month=165, Predicted=189.011976, Expected=188.150000
# 1/1 [==============================] - 0s 22ms/step
# Month=166, Predicted=188.396036, Expected=186.440000
# 1/1 [==============================] - 0s 16ms/step
# Month=167, Predicted=186.907268, Expected=188.180000
# 1/1 [==============================] - 0s 6ms/step
# Month=168, Predicted=188.046284, Expected=186.990000
# 1/1 [==============================] - 0s 4ms/step
# Month=169, Predicted=187.366685, Expected=186.310000
# 1/1 [==============================] - 0s 16ms/step
# Month=170, Predicted=186.597844, Expected=187.630000
# 1/1 [==============================] - 0s 18ms/step
# Month=171, Predicted=187.569447, Expected=187.160000
# 1/1 [==============================] - 0s 18ms/step
# Month=172, Predicted=187.411262, Expected=188.360000
# 1/1 [==============================] - 0s 16ms/step
# Month=173, Predicted=188.320351, Expected=188.150000
# 1/1 [==============================] - 0s 4ms/step
# Month=174, Predicted=188.355971, Expected=188.580000
# 1/1 [==============================] - 0s 15ms/step
# Month=175, Predicted=188.674484, Expected=188.580000
# 1/1 [==============================] - 0s 3ms/step
# Month=176, Predicted=188.749389, Expected=187.900000
# 1/1 [==============================] - 0s 17ms/step
# Month=177, Predicted=188.187844, Expected=187.500000
# 1/1 [==============================] - 0s 6ms/step
# Month=178, Predicted=187.739068, Expected=186.870000
# Test RMSE: 2.460

# %% [markdown]
# ## Over 15 test rows

# %%
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-15], supervised_values[-15:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
cnn_model = fit_cnn(train_scaled, 1, 1, 1)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
cnn_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_cnn(cnn_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-15:], predictions))
print('Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-15:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# X.shape[1]),  1
# X.shape[2])  1
# 875/875 [==============================] - 1s 734us/step
# 1/1 [==============================] - 0s 16ms/step
# Month=1, Predicted=190.371467, Expected=188.590000
# 1/1 [==============================] - 0s 6ms/step
# Month=2, Predicted=188.584465, Expected=188.150000
# 1/1 [==============================] - 0s 17ms/step
# Month=3, Predicted=188.226879, Expected=186.440000
# 1/1 [==============================] - 0s 2ms/step
# Month=4, Predicted=186.413249, Expected=188.180000
# 1/1 [==============================] - 0s 15ms/step
# Month=5, Predicted=188.434764, Expected=186.990000
# 1/1 [==============================] - 0s 21ms/step
# Month=6, Predicted=187.005680, Expected=186.310000
# 1/1 [==============================] - 0s 15ms/step
# Month=7, Predicted=186.367295, Expected=187.630000
# 1/1 [==============================] - 0s 2ms/step
# Month=8, Predicted=187.850493, Expected=187.160000
# 1/1 [==============================] - 0s 8ms/step
# Month=9, Predicted=187.234431, Expected=188.360000
# 1/1 [==============================] - 0s 6ms/step
# Month=10, Predicted=188.570701, Expected=188.150000
# 1/1 [==============================] - 0s 16ms/step
# Month=11, Predicted=188.245647, Expected=188.580000
# 1/1 [==============================] - 0s 8ms/step
# Month=12, Predicted=188.727870, Expected=188.580000
# 1/1 [==============================] - 0s 5ms/step
# Month=13, Predicted=188.692783, Expected=187.900000
# 1/1 [==============================] - 0s 16ms/step
# Month=14, Predicted=187.957295, Expected=187.500000
# 1/1 [==============================] - 0s 20ms/step
# Month=15, Predicted=187.580143, Expected=186.870000
# Test RMSE: 1.072

# %% [markdown]
# # Bi-directional LSTM

# %%
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-178], supervised_values[-178:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
bilstm_model = fit_bilstm(train_scaled, 1, 1, 1)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
bilstm_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_bilstm(bilstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-178:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-178:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# X.shape[1]),  1
# X.shape[2])  1
# 712/712 [==============================] - 1s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# Month=1, Predicted=150.447023, Expected=153.140000
# 1/1 [==============================] - 0s 17ms/step
# Month=2, Predicted=153.157407, Expected=154.230000
# 1/1 [==============================] - 0s 16ms/step
# Month=3, Predicted=154.297040, Expected=153.280000
# 1/1 [==============================] - 0s 17ms/step
# Month=4, Predicted=153.340848, Expected=154.120000
# 1/1 [==============================] - 0s 17ms/step
# Month=5, Predicted=154.231682, Expected=153.810000
# 1/1 [==============================] - 0s 4ms/step
# Month=6, Predicted=153.924784, Expected=154.480000
# 1/1 [==============================] - 0s 17ms/step
# Month=7, Predicted=154.625050, Expected=153.480000
# 1/1 [==============================] - 0s 18ms/step
# Month=8, Predicted=153.596064, Expected=155.390000
# 1/1 [==============================] - 0s 10ms/step
# Month=9, Predicted=155.557007, Expected=155.300000
# 1/1 [==============================] - 0s 17ms/step
# Month=10, Predicted=155.472950, Expected=155.840000
# 1/1 [==============================] - 0s 13ms/step
# Month=11, Predicted=156.027425, Expected=155.900000
# 1/1 [==============================] - 0s 20ms/step
# Month=12, Predicted=156.087490, Expected=156.550000
# 1/1 [==============================] - 0s 18ms/step
# Month=13, Predicted=156.749436, Expected=156.000000
# 1/1 [==============================] - 0s 18ms/step
# Month=14, Predicted=156.178448, Expected=156.990000
# 1/1 [==============================] - 0s 19ms/step
# Month=15, Predicted=157.187848, Expected=159.880000
# 1/1 [==============================] - 0s 3ms/step
# Month=16, Predicted=160.100123, Expected=160.470000
# 1/1 [==============================] - 0s 16ms/step
# Month=17, Predicted=160.721211, Expected=159.760000
# 1/1 [==============================] - 0s 4ms/step
# Month=18, Predicted=159.985496, Expected=155.980000
# 1/1 [==============================] - 0s 16ms/step
# Month=19, Predicted=156.016923, Expected=156.250000
# 1/1 [==============================] - 0s 8ms/step
# Month=20, Predicted=156.345799, Expected=156.170000
# 1/1 [==============================] - 0s 8ms/step
# Month=21, Predicted=156.266029, Expected=157.100000
# 1/1 [==============================] - 0s 9ms/step
# Month=22, Predicted=157.231758, Expected=156.410000
# 1/1 [==============================] - 0s 10ms/step
# Month=23, Predicted=156.524547, Expected=157.410000
# 1/1 [==============================] - 0s 4ms/step
# Month=24, Predicted=157.561616, Expected=163.050000
# 1/1 [==============================] - 0s 17ms/step
# Month=25, Predicted=163.179239, Expected=166.720000
# 1/1 [==============================] - 0s 18ms/step
# Month=26, Predicted=166.921082, Expected=169.040000
# 1/1 [==============================] - 0s 16ms/step
# Month=27, Predicted=169.305884, Expected=166.890000
# 1/1 [==============================] - 0s 28ms/step
# Month=28, Predicted=167.135814, Expected=168.110000
# 1/1 [==============================] - 0s 18ms/step
# Month=29, Predicted=168.356873, Expected=172.500000
# 1/1 [==============================] - 0s 21ms/step
# Month=30, Predicted=172.720547, Expected=174.250000
# 1/1 [==============================] - 0s 19ms/step
# Month=31, Predicted=174.537208, Expected=174.810000
# 1/1 [==============================] - 0s 14ms/step
# Month=32, Predicted=175.113844, Expected=176.240000
# 1/1 [==============================] - 0s 21ms/step
# Month=33, Predicted=176.541046, Expected=175.880000
# 1/1 [==============================] - 0s 17ms/step
# Month=34, Predicted=176.165867, Expected=174.670000
# 1/1 [==============================] - 0s 18ms/step
# Month=35, Predicted=174.893966, Expected=173.970000
# 1/1 [==============================] - 0s 8ms/step
# Month=36, Predicted=174.154743, Expected=171.340000
# 1/1 [==============================] - 0s 20ms/step
# Month=37, Predicted=171.398519, Expected=169.080000
# 1/1 [==============================] - 0s 14ms/step
# Month=38, Predicted=169.063812, Expected=171.100000
# 1/1 [==============================] - 0s 20ms/step
# Month=39, Predicted=171.185468, Expected=170.150000
# 1/1 [==============================] - 0s 19ms/step
# Month=40, Predicted=170.205078, Expected=169.980000
# 1/1 [==============================] - 0s 16ms/step
# Month=41, Predicted=170.054347, Expected=173.140000
# 1/1 [==============================] - 0s 17ms/step
# Month=42, Predicted=173.277397, Expected=174.960000
# 1/1 [==============================] - 0s 19ms/step
# Month=43, Predicted=175.151840, Expected=174.960000
# 1/1 [==============================] - 0s 14ms/step
# Month=44, Predicted=175.170885, Expected=174.970000
# 1/1 [==============================] - 0s 21ms/step
# Month=45, Predicted=175.178531, Expected=174.090000
# 1/1 [==============================] - 0s 14ms/step
# Month=46, Predicted=174.264236, Expected=173.070000
# 1/1 [==============================] - 0s 24ms/step
# Month=47, Predicted=173.204612, Expected=169.480000
# 1/1 [==============================] - 0s 21ms/step
# Month=48, Predicted=169.440335, Expected=171.850000
# 1/1 [==============================] - 0s 23ms/step
# Month=49, Predicted=171.942427, Expected=171.050000
# 1/1 [==============================] - 0s 21ms/step
# Month=50, Predicted=171.118667, Expected=169.800000
# 1/1 [==============================] - 0s 22ms/step
# Month=51, Predicted=169.840966, Expected=169.640000
# 1/1 [==============================] - 0s 20ms/step
# Month=52, Predicted=169.702910, Expected=169.010000
# 1/1 [==============================] - 0s 20ms/step
# Month=53, Predicted=169.065141, Expected=169.320000
# 1/1 [==============================] - 0s 14ms/step
# Month=54, Predicted=169.406228, Expected=169.370000
# 1/1 [==============================] - 0s 16ms/step
# Month=55, Predicted=169.470171, Expected=172.670000
# 1/1 [==============================] - 0s 14ms/step
# Month=56, Predicted=172.823018, Expected=171.700000
# 1/1 [==============================] - 0s 21ms/step
# Month=57, Predicted=171.856531, Expected=172.270000
# 1/1 [==============================] - 0s 19ms/step
# Month=58, Predicted=172.447165, Expected=172.220000
# 1/1 [==============================] - 0s 15ms/step
# Month=59, Predicted=172.397140, Expected=173.970000
# 1/1 [==============================] - 0s 20ms/step
# Month=60, Predicted=174.176779, Expected=176.420000
# 1/1 [==============================] - 0s 18ms/step
# Month=61, Predicted=176.653276, Expected=174.540000
# 1/1 [==============================] - 0s 15ms/step
# Month=62, Predicted=174.731523, Expected=174.350000
# 1/1 [==============================] - 0s 15ms/step
# Month=63, Predicted=174.531121, Expected=175.010000
# 1/1 [==============================] - 0s 15ms/step
# Month=64, Predicted=175.202613, Expected=175.010000
# 1/1 [==============================] - 0s 18ms/step
# Month=65, Predicted=175.197638, Expected=175.010000
# 1/1 [==============================] - 0s 12ms/step
# Month=66, Predicted=175.192490, Expected=170.570000
# 1/1 [==============================] - 0s 22ms/step
# Month=67, Predicted=170.523539, Expected=170.600000
# 1/1 [==============================] - 0s 26ms/step
# Month=68, Predicted=170.638259, Expected=171.080000
# 1/1 [==============================] - 0s 18ms/step
# Month=69, Predicted=171.145444, Expected=169.230000
# 1/1 [==============================] - 0s 18ms/step
# Month=70, Predicted=169.229046, Expected=169.230000
# 1/1 [==============================] - 0s 15ms/step
# Month=71, Predicted=169.271458, Expected=172.260000
# 1/1 [==============================] - 0s 19ms/step
# Month=72, Predicted=172.373095, Expected=172.230000
# 1/1 [==============================] - 0s 14ms/step
# Month=73, Predicted=172.369405, Expected=173.030000
# 1/1 [==============================] - 0s 22ms/step
# Month=74, Predicted=173.200229, Expected=175.000000
# 1/1 [==============================] - 0s 12ms/step
# Month=75, Predicted=175.205415, Expected=174.350000
# 1/1 [==============================] - 0s 17ms/step
# Month=76, Predicted=174.550156, Expected=174.330000
# 1/1 [==============================] - 0s 4ms/step
# Month=77, Predicted=174.524335, Expected=174.290000
# 1/1 [==============================] - 0s 15ms/step
# Month=78, Predicted=174.477330, Expected=175.280000
# 1/1 [==============================] - 0s 4ms/step
# Month=79, Predicted=175.484232, Expected=177.090000
# 1/1 [==============================] - 0s 17ms/step
# Month=80, Predicted=177.317764, Expected=177.090000
# 1/1 [==============================] - 0s 19ms/step
# Month=81, Predicted=177.321363, Expected=176.190000
# 1/1 [==============================] - 0s 16ms/step
# Month=82, Predicted=176.383113, Expected=179.100000
# 1/1 [==============================] - 0s 19ms/step
# Month=83, Predicted=179.317814, Expected=179.260000
# 1/1 [==============================] - 0s 16ms/step
# Month=84, Predicted=179.496870, Expected=178.460000
# 1/1 [==============================] - 0s 5ms/step
# Month=85, Predicted=178.664196, Expected=177.000000
# 1/1 [==============================] - 0s 14ms/step
# Month=86, Predicted=177.141320, Expected=177.040000
# 1/1 [==============================] - 0s 17ms/step
# Month=87, Predicted=177.186794, Expected=174.220000
# 1/1 [==============================] - 0s 5ms/step
# Month=88, Predicted=174.235451, Expected=171.110000
# 1/1 [==============================] - 0s 19ms/step
# Month=89, Predicted=171.014288, Expected=171.510000
# 1/1 [==============================] - 0s 18ms/step
# Month=90, Predicted=171.505898, Expected=167.960000
# 1/1 [==============================] - 0s 8ms/step
# Month=91, Predicted=167.786949, Expected=166.970000
# 1/1 [==============================] - 0s 19ms/step
# Month=92, Predicted=166.860342, Expected=167.430000
# 1/1 [==============================] - 0s 16ms/step
# Month=93, Predicted=167.380792, Expected=167.780000
# 1/1 [==============================] - 0s 24ms/step
# Month=94, Predicted=167.770712, Expected=160.500000
# 1/1 [==============================] - 0s 3ms/step
# Month=95, Predicted=160.104827, Expected=156.490000
# 1/1 [==============================] - 0s 16ms/step
# Month=96, Predicted=156.145363, Expected=163.030000
# 1/1 [==============================] - 0s 6ms/step
# Month=97, Predicted=162.908759, Expected=159.540000
# 1/1 [==============================] - 0s 3ms/step
# Month=98, Predicted=159.285702, Expected=155.150000
# 1/1 [==============================] - 0s 17ms/step
# Month=99, Predicted=154.813028, Expected=156.410000
# 1/1 [==============================] - 0s 6ms/step
# Month=100, Predicted=156.272868, Expected=162.710000
# 1/1 [==============================] - 0s 18ms/step
# Month=101, Predicted=162.637148, Expected=164.340000
# 1/1 [==============================] - 0s 21ms/step
# Month=102, Predicted=164.396999, Expected=167.370000
# 1/1 [==============================] - 0s 16ms/step
# Month=103, Predicted=167.500814, Expected=172.990000
# 1/1 [==============================] - 0s 23ms/step
# Month=104, Predicted=173.098463, Expected=172.430000
# 1/1 [==============================] - 0s 10ms/step
# Month=105, Predicted=172.668909, Expected=172.430000
# 1/1 [==============================] - 0s 6ms/step
# Month=106, Predicted=172.667756, Expected=171.850000
# 1/1 [==============================] - 0s 17ms/step
# Month=107, Predicted=172.067479, Expected=171.070000
# 1/1 [==============================] - 0s 20ms/step
# Month=108, Predicted=171.253625, Expected=172.500000
# 1/1 [==============================] - 0s 14ms/step
# Month=109, Predicted=172.707886, Expected=175.500000
# 1/1 [==============================] - 0s 13ms/step
# Month=110, Predicted=175.726623, Expected=178.970000
# 1/1 [==============================] - 0s 17ms/step
# Month=111, Predicted=179.211731, Expected=178.390000
# 1/1 [==============================] - 0s 16ms/step
# Month=112, Predicted=178.667064, Expected=178.120000
# 1/1 [==============================] - 0s 4ms/step
# Month=113, Predicted=178.371667, Expected=175.000000
# 1/1 [==============================] - 0s 2ms/step
# Month=114, Predicted=175.103287, Expected=176.210000
# 1/1 [==============================] - 0s 8ms/step
# Month=115, Predicted=176.369701, Expected=176.820000
# 1/1 [==============================] - 0s 10ms/step
# Month=116, Predicted=176.992441, Expected=176.670000
# 1/1 [==============================] - 0s 16ms/step
# Month=117, Predicted=176.837527, Expected=175.030000
# 1/1 [==============================] - 0s 17ms/step
# Month=118, Predicted=175.133219, Expected=176.940000
# 1/1 [==============================] - 0s 17ms/step
# Month=119, Predicted=177.101145, Expected=179.980000
# 1/1 [==============================] - 0s 18ms/step
# Month=120, Predicted=180.174233, Expected=181.720000
# 1/1 [==============================] - 0s 18ms/step
# Month=121, Predicted=181.960782, Expected=179.970000
# 1/1 [==============================] - 0s 19ms/step
# Month=122, Predicted=180.169991, Expected=178.440000
# 1/1 [==============================] - 0s 4ms/step
# Month=123, Predicted=178.577138, Expected=178.650000
# 1/1 [==============================] - 0s 17ms/step
# Month=124, Predicted=178.799724, Expected=178.020000
# 1/1 [==============================] - 0s 5ms/step
# Month=125, Predicted=178.146339, Expected=175.300000
# 1/1 [==============================] - 0s 4ms/step
# Month=126, Predicted=175.306434, Expected=175.240000
# 1/1 [==============================] - 0s 17ms/step
# Month=127, Predicted=175.291706, Expected=171.270000
# 1/1 [==============================] - 0s 19ms/step
# Month=128, Predicted=171.126188, Expected=168.850000
# 1/1 [==============================] - 0s 18ms/step
# Month=129, Predicted=168.693431, Expected=164.940000
# 1/1 [==============================] - 0s 16ms/step
# Month=130, Predicted=164.652210, Expected=172.770000
# 1/1 [==============================] - 0s 19ms/step
# Month=131, Predicted=172.671854, Expected=168.340000
# 1/1 [==============================] - 0s 8ms/step
# Month=132, Predicted=168.103057, Expected=166.480000
# 1/1 [==============================] - 0s 28ms/step
# Month=133, Predicted=166.307874, Expected=167.780000
# 1/1 [==============================] - 0s 16ms/step
# Month=134, Predicted=167.725137, Expected=167.780000
# 1/1 [==============================] - 0s 15ms/step
# Month=135, Predicted=167.754382, Expected=166.680000
# 1/1 [==============================] - 0s 21ms/step
# Month=136, Predicted=166.650150, Expected=168.390000
# 1/1 [==============================] - 0s 19ms/step
# Month=137, Predicted=168.451107, Expected=171.610000
# 1/1 [==============================] - 0s 2ms/step
# Month=138, Predicted=171.732259, Expected=172.800000
# 1/1 [==============================] - 0s 15ms/step
# Month=139, Predicted=172.985085, Expected=168.380000
# 1/1 [==============================] - 0s 20ms/step
# Month=140, Predicted=168.380171, Expected=170.050000
# 1/1 [==============================] - 0s 16ms/step
# Month=141, Predicted=170.161313, Expected=173.250000
# 1/1 [==============================] - 0s 22ms/step
# Month=142, Predicted=173.406300, Expected=172.440000
# 1/1 [==============================] - 0s 16ms/step
# Month=143, Predicted=172.608508, Expected=174.140000
# 1/1 [==============================] - 0s 4ms/step
# Month=144, Predicted=174.341814, Expected=174.730000
# 1/1 [==============================] - 0s 17ms/step
# Month=145, Predicted=174.951930, Expected=175.820000
# 1/1 [==============================] - 0s 18ms/step
# Month=146, Predicted=176.057422, Expected=178.240000
# 1/1 [==============================] - 0s 5ms/step
# Month=147, Predicted=178.492455, Expected=177.840000
# 1/1 [==============================] - 0s 2ms/step
# Month=148, Predicted=178.096995, Expected=172.800000
# 1/1 [==============================] - 0s 6ms/step
# Month=149, Predicted=172.792612, Expected=165.720000
# 1/1 [==============================] - 0s 22ms/step
# Month=150, Predicted=165.371400, Expected=165.240000
# 1/1 [==============================] - 0s 3ms/step
# Month=151, Predicted=165.097601, Expected=162.940000
# 1/1 [==============================] - 0s 16ms/step
# Month=152, Predicted=162.708025, Expected=163.650000
# 1/1 [==============================] - 0s 5ms/step
# Month=153, Predicted=163.536173, Expected=164.220000
# 1/1 [==============================] - 0s 2ms/step
# Month=154, Predicted=164.152488, Expected=162.320000
# 1/1 [==============================] - 0s 11ms/step
# Month=155, Predicted=162.206200, Expected=165.260000
# 1/1 [==============================] - 0s 19ms/step
# Month=156, Predicted=165.284034, Expected=169.100000
# 1/1 [==============================] - 0s 17ms/step
# Month=157, Predicted=169.187595, Expected=176.570000
# 1/1 [==============================] - 0s 20ms/step
# Month=158, Predicted=176.571942, Expected=176.890000
# 1/1 [==============================] - 0s 20ms/step
# Month=159, Predicted=177.095937, Expected=183.830000
# 1/1 [==============================] - 0s 16ms/step
# Month=160, Predicted=183.887215, Expected=185.160000
# 1/1 [==============================] - 0s 2ms/step
# Month=161, Predicted=185.407717, Expected=186.050000
# 1/1 [==============================] - 0s 16ms/step
# Month=162, Predicted=186.332857, Expected=187.360000
# 1/1 [==============================] - 0s 17ms/step
# Month=163, Predicted=187.654497, Expected=190.040000
# 1/1 [==============================] - 0s 17ms/step
# Month=164, Predicted=190.330270, Expected=188.590000
# 1/1 [==============================] - 0s 16ms/step
# Month=165, Predicted=188.870070, Expected=188.150000
# 1/1 [==============================] - 0s 15ms/step
# Month=166, Predicted=188.391216, Expected=186.440000
# 1/1 [==============================] - 0s 21ms/step
# Month=167, Predicted=186.600701, Expected=188.180000
# 1/1 [==============================] - 0s 19ms/step
# Month=168, Predicted=188.377869, Expected=186.990000
# 1/1 [==============================] - 0s 1ms/step
# Month=169, Predicted=187.144578, Expected=186.310000
# 1/1 [==============================] - 0s 5ms/step
# Month=170, Predicted=186.442657, Expected=187.630000
# 1/1 [==============================] - 0s 17ms/step
# Month=171, Predicted=187.798722, Expected=187.160000
# 1/1 [==============================] - 0s 16ms/step
# Month=172, Predicted=187.314810, Expected=188.360000
# 1/1 [==============================] - 0s 2ms/step
# Month=173, Predicted=188.544304, Expected=188.150000
# 1/1 [==============================] - 0s 19ms/step
# Month=174, Predicted=188.329151, Expected=188.580000
# 1/1 [==============================] - 0s 21ms/step
# Month=175, Predicted=188.768047, Expected=188.580000
# 1/1 [==============================] - 0s 22ms/step
# Month=176, Predicted=188.764391, Expected=187.900000
# 1/1 [==============================] - 0s 19ms/step
# Month=177, Predicted=188.057909, Expected=187.500000
# 1/1 [==============================] - 0s 14ms/step
# Month=178, Predicted=187.644333, Expected=186.870000
#
#  Test RMSE: 2.377

# %% [markdown]
# ## Over 15 test rows

# %%
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-10], supervised_values[-10:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
bilstm_model = fit_bilstm(train_scaled, 1, 1, 1)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
bilstm_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_bilstm(bilstm_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-10:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-10:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# X.shape[1]),  1
# X.shape[2])  1
# 880/880 [==============================] - 2s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# Month=1, Predicted=187.078989, Expected=186.310000
# 1/1 [==============================] - 0s 16ms/step
# Month=2, Predicted=186.383407, Expected=187.630000
# 1/1 [==============================] - 0s 7ms/step
# Month=3, Predicted=187.780205, Expected=187.160000
# 1/1 [==============================] - 0s 5ms/step
# Month=4, Predicted=187.274215, Expected=188.360000
# 1/1 [==============================] - 0s 12ms/step
# Month=5, Predicted=188.526743, Expected=188.150000
# 1/1 [==============================] - 0s 16ms/step
# Month=6, Predicted=188.282982, Expected=188.580000
# 1/1 [==============================] - 0s 6ms/step
# Month=7, Predicted=188.722306, Expected=188.580000
# 1/1 [==============================] - 0s 16ms/step
# Month=8, Predicted=188.709540, Expected=187.900000
# 1/1 [==============================] - 0s 12ms/step
# Month=9, Predicted=187.996964, Expected=187.500000
# 1/1 [==============================] - 0s 3ms/step
# Month=10, Predicted=187.590900, Expected=186.870000
#
#  Test RMSE: 0.734

# %% [markdown]
# # Arima Model

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\dhruv\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\dhruv\anaconda3\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy>=1.3 in c:\users\dhruv\anaconda3\lib\site-packages (from statsmodels) (1.9.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\dhruv\anaconda3\lib\site-packages (from statsmodels) (1.4.4)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\dhruv\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\dhruv\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dhruv\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dhruv\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhruv\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: six in c:\users\dhruv\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
data_stock_np = np.array(data_stock)

# %%
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
import numpy as np
from matplotlib import pyplot

#data = data[['Date']]
data = np.asarray(data_stock_np)

# %%
model = ARIMA(data, order=(5,1,5))

model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  891
# Model:                 ARIMA(5, 1, 5)   Log Likelihood               -1799.085
# Date:                Fri, 21 Apr 2023   AIC                           3620.170
# Time:                        18:15:37   BIC                           3672.873
# Sample:                             0   HQIC                          3640.314
#                                 - 891
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2913      0.793     -1.629      0.103      -2.845       0.262
# ar.L2         -0.8198      1.749     -0.469      0.639      -4.248       2.609
# ar.L3          0.5007      2.225      0.225      0.822      -3.861       4.863
# ar.L4          0.8564      1.567      0.547      0.585      -2.214       3.927
# ar.L5          0.7268      0.669      1.087      0.277      -0.584       2.037
# ma.L1          1.3316      0.797      1.672      0.095      -0.230       2.893
# ma.L2          0.8398      1.792      0.469      0.639      -2.672       4.352
# ma.L3         -0.5359      2.288     -0.234      0.815      -5.020       3.949
# ma.L4         -0.8670      1.589     -0.546      0.585      -3.982       2.248
# ma.L5         -0.6983      0.663     -1.054      0.292      -1.997       0.601
# sigma2         3.4022      0.114     29.722      0.000       3.178       3.627
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.67   Jarque-Bera (JB):               233.78
# Prob(Q):                              0.41   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                             0.03
# Prob(H) (two-sided):                  0.15   Kurtosis:                         5.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\dhruv\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                 0
# count  891.000000
# mean     0.206538
# std      4.121103
# min     -7.096568
# 25%     -0.749766
# 50%      0.050407
# 75%      0.965833
# max    110.380000

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
X = data
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)

pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=143.608176, expected=144.770000
# predicted=144.784362, expected=144.020000
# predicted=143.977548, expected=143.660000
# predicted=143.644291, expected=143.340000
# predicted=143.377365, expected=143.170000
# predicted=143.160002, expected=141.630000
# predicted=141.657881, expected=141.800000
# predicted=141.878979, expected=141.050000
# predicted=141.114360, expected=141.050000
# predicted=141.078864, expected=141.830000
# predicted=141.928846, expected=141.200000
# predicted=141.160754, expected=140.680000
# predicted=140.688279, expected=142.440000
# predicted=142.505570, expected=142.270000
# predicted=142.200036, expected=143.640000
# predicted=143.610734, expected=144.530000
# predicted=144.512529, expected=143.680000
# predicted=143.517691, expected=143.790000
# predicted=143.783120, expected=143.650000
# predicted=143.626870, expected=146.580000
# predicted=146.588935, expected=147.510000
# predicted=147.453348, expected=147.060000
# predicted=146.890607, expected=146.530000
# predicted=146.490825, expected=148.960000
# predicted=148.934495, expected=153.010000
# predicted=152.993657, expected=153.990000
# predicted=153.768625, expected=153.260000
# predicted=153.048311, expected=153.950000
# predicted=153.905016, expected=156.100000
# predicted=156.071392, expected=155.700000
# predicted=155.553400, expected=155.470000
# predicted=155.415367, expected=150.250000
# predicted=150.164348, expected=152.540000
# predicted=152.728483, expected=153.060000
# predicted=153.238782, expected=153.990000
# predicted=153.823913, expected=153.800000
# predicted=153.861755, expected=153.340000
# predicted=153.256333, expected=153.870000
# predicted=153.904007, expected=153.610000
# predicted=153.591962, expected=153.610000
# predicted=153.592076, expected=153.670000
# predicted=153.696654, expected=152.760000
# predicted=152.732906, expected=153.180000
# predicted=153.220893, expected=155.450000
# predicted=155.514709, expected=153.930000
# predicted=153.793858, expected=154.450000
# predicted=154.421143, expected=155.370000
# predicted=155.446025, expected=154.990000
# predicted=154.873265, expected=148.980000
# predicted=148.910361, expected=145.420000
# predicted=145.591930, expected=146.590000
# predicted=147.055564, expected=145.160000
# predicted=145.168058, expected=144.290000
# predicted=144.359509, expected=142.270000
# predicted=142.397389, expected=146.340000
# predicted=146.487528, expected=145.010000
# predicted=144.937566, expected=145.870000
# predicted=145.711761, expected=145.630000
# predicted=145.806805, expected=146.280000
# predicted=146.117969, expected=145.820000
# predicted=145.857524, expected=143.730000
# predicted=143.652456, expected=145.830000
# predicted=145.983037, expected=143.680000
# predicted=143.653894, expected=144.020000
# predicted=143.962008, expected=143.500000
# predicted=143.684130, expected=143.500000
# predicted=143.403557, expected=144.090000
# predicted=144.177328, expected=142.730000
# predicted=142.676737, expected=144.180000
# predicted=144.222570, expected=145.060000
# predicted=145.095783, expected=145.530000
# predicted=145.394309, expected=145.740000
# predicted=145.743037, expected=147.770000
# predicted=147.751484, expected=149.040000
# predicted=148.970783, expected=149.560000
# predicted=149.426942, expected=150.080000
# predicted=150.056443, expected=151.020000
# predicted=150.982990, expected=150.340000
# predicted=150.263560, expected=150.270000
# predicted=150.250632, expected=152.090000
# predicted=152.158403, expected=152.740000
# predicted=152.655729, expected=153.460000
# predicted=153.380697, expected=150.560000
# predicted=150.516177, expected=149.500000
# predicted=149.529135, expected=148.730000
# predicted=148.894920, expected=150.050000
# predicted=150.061674, expected=157.140000
# predicted=157.298472, expected=155.570000
# predicted=155.223972, expected=156.390000
# predicted=156.113198, expected=158.810000
# predicted=158.964885, expected=160.080000
# predicted=159.844606, expected=161.060000
# predicted=160.962914, expected=155.320000
# predicted=155.190061, expected=157.480000
# predicted=157.657067, expected=159.850000
# predicted=160.060587, expected=161.600000
# predicted=161.292528, expected=160.950000
# predicted=160.808186, expected=157.860000
# predicted=157.822865, expected=157.500000
# predicted=157.709911, expected=157.210000
# predicted=157.389418, expected=159.780000
# predicted=159.779478, expected=159.980000
# predicted=159.860220, expected=159.270000
# predicted=159.097755, expected=159.860000
# predicted=159.924039, expected=161.470000
# predicted=161.526823, expected=162.910000
# predicted=162.812421, expected=163.350000
# predicted=163.206146, expected=164.000000
# predicted=163.944490, expected=164.050000
# predicted=164.042793, expected=164.050000
# predicted=164.034563, expected=162.080000
# predicted=162.070361, expected=161.910000
# predicted=161.996565, expected=161.260000
# predicted=161.372041, expected=158.630000
# predicted=158.595545, expected=161.500000
# predicted=161.650501, expected=160.860000
# predicted=160.870034, expected=159.650000
# predicted=159.468123, expected=158.280000
# predicted=158.377098, expected=159.880000
# predicted=160.028153, expected=158.670000
# predicted=158.641016, expected=158.730000
# predicted=158.659503, expected=156.070000
# predicted=156.142117, expected=153.390000
# predicted=153.457393, expected=151.890000
# predicted=152.110045, expected=150.550000
# predicted=150.671360, expected=153.140000
# predicted=153.233350, expected=154.230000
# predicted=154.173851, expected=153.280000
# predicted=153.043985, expected=154.120000
# predicted=154.138635, expected=153.810000
# predicted=153.864596, expected=154.480000
# predicted=154.448764, expected=153.480000
# predicted=153.465203, expected=155.390000
# predicted=155.412248, expected=155.300000
# predicted=155.291327, expected=155.840000
# predicted=155.729683, expected=155.900000
# predicted=155.910698, expected=156.550000
# predicted=156.537241, expected=156.000000
# predicted=155.975711, expected=156.990000
# predicted=156.988816, expected=159.880000
# predicted=159.918674, expected=160.470000
# predicted=160.308911, expected=159.760000
# predicted=159.582725, expected=155.980000
# predicted=155.980134, expected=156.250000
# predicted=156.479871, expected=156.170000
# predicted=156.378974, expected=157.100000
# predicted=157.027632, expected=156.410000
# predicted=156.343657, expected=157.410000
# predicted=157.391133, expected=163.050000
# predicted=163.150562, expected=166.720000
# predicted=166.524634, expected=169.040000
# predicted=168.673134, expected=166.890000
# predicted=166.635780, expected=168.110000
# predicted=168.208157, expected=172.500000
# predicted=172.845619, expected=174.250000
# predicted=174.062989, expected=174.810000
# predicted=174.504634, expected=176.240000
# predicted=176.342418, expected=175.880000
# predicted=175.942899, expected=174.670000
# predicted=174.617099, expected=173.970000
# predicted=174.061660, expected=171.340000
# predicted=171.356851, expected=169.080000
# predicted=169.078673, expected=171.100000
# predicted=171.347921, expected=170.150000
# predicted=170.083702, expected=169.980000
# predicted=169.792521, expected=173.140000
# predicted=173.315315, expected=174.960000
# predicted=174.918953, expected=174.960000
# predicted=174.723959, expected=174.970000
# predicted=174.961691, expected=174.090000
# predicted=174.140242, expected=173.070000
# predicted=173.082228, expected=169.480000
# predicted=169.424716, expected=171.850000
# predicted=172.085613, expected=171.050000
# predicted=171.095977, expected=169.800000
# predicted=169.574254, expected=169.640000
# predicted=169.748975, expected=169.010000
# predicted=169.056409, expected=169.320000
# predicted=169.322226, expected=169.370000
# predicted=169.376246, expected=172.670000
# predicted=172.745127, expected=171.700000
# predicted=171.558394, expected=172.270000
# predicted=172.159592, expected=172.220000
# predicted=172.327775, expected=173.970000
# predicted=173.994698, expected=176.420000
# predicted=176.450407, expected=174.540000
# predicted=174.318845, expected=174.350000
# predicted=174.329806, expected=175.010000
# predicted=175.210343, expected=175.010000
# predicted=174.977154, expected=175.010000
# predicted=174.951830, expected=170.570000
# predicted=170.448733, expected=170.600000
# predicted=170.761967, expected=171.080000
# predicted=171.313344, expected=169.230000
# predicted=169.044262, expected=169.230000
# predicted=169.205224, expected=172.260000
# predicted=172.446143, expected=172.230000
# predicted=172.073558, expected=173.030000
# predicted=172.901721, expected=175.000000
# predicted=175.105550, expected=174.350000
# predicted=174.247722, expected=174.330000
# predicted=174.289005, expected=174.290000
# predicted=174.368797, expected=175.280000
# predicted=175.312432, expected=177.090000
# predicted=177.103726, expected=177.090000
# predicted=176.980840, expected=176.190000
# predicted=176.108623, expected=179.100000
# predicted=179.273490, expected=179.260000
# predicted=179.210073, expected=178.460000
# predicted=178.292349, expected=177.000000
# predicted=177.045540, expected=177.040000
# predicted=177.160714, expected=174.220000
# predicted=174.174416, expected=171.110000
# predicted=171.064688, expected=171.510000
# predicted=171.741778, expected=167.960000
# predicted=167.865063, expected=166.970000
# predicted=166.932906, expected=167.430000
# predicted=167.582725, expected=167.780000
# predicted=167.718477, expected=160.500000
# predicted=160.176407, expected=156.490000
# predicted=156.565135, expected=163.030000
# predicted=163.706095, expected=159.540000
# predicted=158.937960, expected=155.150000
# predicted=154.902993, expected=156.410000
# predicted=157.028934, expected=162.710000
# predicted=162.616797, expected=164.340000
# predicted=163.693683, expected=167.370000
# predicted=167.388306, expected=172.990000
# predicted=173.401282, expected=172.430000
# predicted=172.037684, expected=172.430000
# predicted=172.581878, expected=171.850000
# predicted=172.073463, expected=171.070000
# predicted=170.930845, expected=172.500000
# predicted=172.617247, expected=175.500000
# predicted=175.522977, expected=178.970000
# predicted=178.929378, expected=178.390000
# predicted=178.231151, expected=178.120000
# predicted=178.247289, expected=175.000000
# predicted=174.979272, expected=176.210000
# predicted=176.357550, expected=176.820000
# predicted=176.808474, expected=176.670000
# predicted=176.468943, expected=175.030000
# predicted=175.068518, expected=176.940000
# predicted=177.131069, expected=179.980000
# predicted=180.009557, expected=181.720000
# predicted=181.523586, expected=179.970000
# predicted=179.870471, expected=178.440000
# predicted=178.571190, expected=178.650000
# predicted=178.818452, expected=178.020000
# predicted=177.878024, expected=175.300000
# predicted=175.152800, expected=175.240000
# predicted=175.451087, expected=171.270000
# predicted=171.071466, expected=168.850000
# predicted=168.813734, expected=164.940000
# predicted=164.920258, expected=172.770000
# predicted=173.170128, expected=168.340000
# predicted=167.830634, expected=166.480000
# predicted=166.317813, expected=167.780000
# predicted=168.565124, expected=167.780000
# predicted=167.291035, expected=166.680000
# predicted=166.618044, expected=168.390000
# predicted=168.633016, expected=171.610000
# predicted=171.596896, expected=172.800000
# predicted=172.575615, expected=168.380000
# predicted=168.257332, expected=170.050000
# predicted=170.512532, expected=173.250000
# predicted=173.285095, expected=172.440000
# predicted=171.863264, expected=174.140000
# predicted=174.443163, expected=174.730000
# predicted=174.807786, expected=175.820000
# predicted=175.669052, expected=178.240000
# predicted=178.376362, expected=177.840000
# predicted=177.671460, expected=172.800000
# predicted=172.696843, expected=165.720000
# predicted=165.849475, expected=165.240000
# predicted=165.639208, expected=162.940000
# predicted=162.622756, expected=163.650000
# predicted=163.560757, expected=164.220000
# predicted=164.431583, expected=162.320000
# predicted=162.074659, expected=165.260000
# predicted=165.596173, expected=169.100000
# predicted=169.127261, expected=176.570000
# predicted=176.627510, expected=176.890000
# predicted=176.693903, expected=183.830000
# predicted=184.347149, expected=185.160000
# predicted=185.366108, expected=186.050000
# predicted=185.830058, expected=187.360000
# predicted=187.876054, expected=190.040000
# predicted=190.065010, expected=188.590000
# predicted=188.440431, expected=188.150000
# predicted=188.244308, expected=186.440000
# predicted=186.500263, expected=188.180000
# predicted=188.147654, expected=186.990000
# predicted=186.880177, expected=186.310000
# predicted=186.195659, expected=187.630000
# predicted=187.911454, expected=187.160000
# predicted=186.946631, expected=188.360000
# predicted=188.434007, expected=188.150000
# predicted=188.215764, expected=188.580000
# predicted=188.537432, expected=188.580000
# predicted=188.667736, expected=187.900000
# predicted=187.808694, expected=187.500000
# predicted=187.535881, expected=186.870000
# Test RMSE: 2.146

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
X = data
size = 876
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,1))
	model_fit = model.fit()
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes
pyplot.plot(test)

pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=190.044872, expected=188.590000
# predicted=188.250655, expected=188.150000
# predicted=188.039589, expected=186.440000
# predicted=186.285019, expected=188.180000
# predicted=187.965794, expected=186.990000
# predicted=186.603642, expected=186.310000
# predicted=185.976972, expected=187.630000
# predicted=187.693149, expected=187.160000
# predicted=186.828260, expected=188.360000
# predicted=188.257964, expected=188.150000
# predicted=188.076102, expected=188.580000
# predicted=188.450624, expected=188.580000
# predicted=188.540920, expected=187.900000
# predicted=187.723895, expected=187.500000
# predicted=187.417436, expected=186.870000
# Test RMSE: 1.024

# %% [markdown]
# # Make results for comparision

# %%
plt.figure(figsize=(9, 5))

# models 
Models_used = ["LSTM Model", "RNN Model", "CNN Model","BiLSTM Model","Arima Model"]

# metrics of the model in list format
rmse_of_models = [0.932,1.558, 1.317 ,0.773,1.028]

plt.barh(Models_used, rmse_of_models)
plt.xlabel("Root mean square error") 
for index, value in enumerate(rmse_of_models):
    plt.text(value, index,
             str(value))
  
plt.show()

# %% [markdown]
# # Implementing Gated Recurrent Unit (GRU) Neural Network

# %%
from tensorflow.keras.layers import GRU

# %%
def fit_gru(train, batchSize, epoch):
	X, y = train[:, 0:-1], train[:, -1]
	X = X.reshape(X.shape[0], 1, X.shape[1])
	model = Sequential()
	model.add(GRU(units=64, activation='tanh', batch_input_shape=(batchSize, X.shape[1], X.shape[2])))
	model.add(Dense(1))
	model.compile(loss='mean_squared_error', optimizer='adam')
	for i in range(epoch):
		model.fit(X, y, epochs=1, batch_size=batchSize, verbose=0, shuffle=False)
		model.reset_states()
	return model

# %%
def forecast_gru(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# %%
# modify data to be stationary
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-178], supervised_values[-178:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
gru_model = fit_gru(train_scaled, 1, 1)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
gru_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_gru(gru_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	#print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-178:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-178:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# 712/712 [==============================] - 1s 1ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
#
#  Test RMSE: 2.371

# %%
# modify data to be stationary
raw_values = np.array(data_stock)
diff_values = difference(raw_values, 1)
# modify data to be supervised 
supervised = series_data_to_supervised_data(diff_values, 1)
supervised_values = supervised.values

# split data 
train, test = supervised_values[0:-15], supervised_values[-15:]

# modify the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)
 
# fit the model
gru_model = fit_gru(train_scaled, 1, 1)

# forecast 
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
gru_model.predict(train_reshaped, batch_size=1)
 
# walk-forward validation on the test data
predictions = list()
for i in range(len(test_scaled)):
	# make one-step forecast
	X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
	yhat = forecast_gru(gru_model, 1, X)
	# invert scaling
	yhat = invert_scale(scaler, X, yhat)
  
	yhat = inverse_the_difference(raw_values, yhat, len(test_scaled)-i+1)
	# store forecast
	predictions.append(yhat)
	expected = raw_values[len(train) + i + 1]
	#print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
 

##print("X and y data : ", X ," y = ",y )
#print("yhat = ", yhat)
# report performance
rmse = sqrt(mean_squared_error(raw_values[-15:], predictions))
print('\n Test RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(raw_values[-15:])
pyplot.plot(predictions)
pyplot.show()
# Out:
# 875/875 [==============================] - 1s 810us/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
#
#  Test RMSE: 1.092

# %% [markdown]
# # **Model Comparison**

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(9, 5))

# models 
Models_used = ["LSTM Model", "RNN Model", "CNN Model","BiLSTM Model","Arima Model"]

# metrics of the model in list format
rmse_of_models = [0.932,1.558, 1.317 ,0.773,1.028]
pyplot.barh(Models_used, rmse_of_models)
pyplot.barh("GRU Model", 1.092)
pyplot.xlabel("Root mean square error") 
for index, value in enumerate(rmse_of_models):
    pyplot.text(value, index,
             str(value))
pyplot.text(1.088, 5, str(1.092))
  
pyplot.show()

# %% [markdown]
# # References:

# %% [markdown]
# [1]: R. Khandelwal, P. Marfatia, S. Shah, V. Joshi, P. Kamath and K. Chavan, "Financial Data Time Series Forecasting Using Neural Networks and a Comparative Study," 2022 International Conference for Advancement in Technology (ICONAT), Goa, India, 2022, pp. 1-6, doi: 10.1109/ICONAT53423.2022.9725845.
#
# [2]: R. Khandelwal (2022, January 28). Financial-Data-Time-Series-Forecasting-Using-Neural-Networks. https://github.com/ritvik02/Financial-Data-Time-Series-Forecasting-Using-Neural-Networks
